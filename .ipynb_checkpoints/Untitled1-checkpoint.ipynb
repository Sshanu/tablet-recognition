-- %%
a1 = image.load('images/diff/back/img_2.jpg',3,'byte')
a2=image.scale(a1,500,500):double()
itorch.image(a2)
b = torch.randn(500,500)*20
c = torch.Tensor(1,500,500):fill(10)
d = torch.Tensor(1,500,500):fill(10)
a3 = a2
a3[1] = a2[1]+b
itorch.image(a3)
-- Out:
-- Console does not support images
-- Console does not support images
